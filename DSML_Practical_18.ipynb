# %% [markdown]
# 18. Use House_Price prediction dataset. Provide summary statistics (mean,
# median, minimum, maximum, standard deviation) of variables (categorical
# vs quantitative) such as- For example, if categorical variable is age groups
# and quantitative variable is income, then provide summary statistics of
# income grouped by the age groups.

# %%
import seaborn as sns
import pandas as pd
# Out:
# C:\Users\RUTUJA\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df=pd.read_csv("D:\Datasets\Datasets\House Data.csv")
df
# Out:
#        Unnamed: 0     district         price  \
# 0               0       adalar   3,100,000TL
# 1               1       adalar   1,600,000TL
# 2               2       adalar  18,500,000TL
# 3               3       adalar   9,500,000TL
# 4               4       adalar  25,000,000TL
# ...           ...          ...           ...
# 25150       25150  zeytinburnu   1,850,000TL
# 25151       25151  zeytinburnu   1,100,000TL
# 25152       25152  zeytinburnu   9,000,000TL
# 25153       25153  zeytinburnu  13,000,000TL
# 25154       25154  zeytinburnu   1,000,000TL
#
#                                                  address    AdUpdateDate  \
# 0      ['Anasayfa', 'Satılık Daire', 'İstanbul Satılı...   24 Şubat 2022
# 1      ['Anasayfa', 'Satılık Daire', 'İstanbul Satılı...    02 Mart 2022
# 2      ['Anasayfa', 'Satılık Müstakil Ev', 'İstanbul ...   11 Şubat 2022
# 3      ['Anasayfa', 'Satılık Bina', 'İstanbul Satılık...   11 Şubat 2022
# ...

# %%
df.shape
# Out:
# (25155, 38)

# %%
df.size
# Out:
# 955890

# %%
df['price'] = df['price'].str.replace('TL', '')

# %%
df.mean()
# Out:
# C:\Users\RUTUJA\AppData\Local\Temp\ipykernel_18724\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# Unnamed: 0                12577.000000
# NumberFloorsofBuilding        7.757782
# dtype: float64

# %%
df.median()
# Out:
# C:\Users\RUTUJA\AppData\Local\Temp\ipykernel_18724\530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# Unnamed: 0                12577.0
# NumberFloorsofBuilding        5.0
# dtype: float64

# %%
df.std()
# Out:
# C:\Users\RUTUJA\AppData\Local\Temp\ipykernel_18724\3390915376.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# Unnamed: 0                7261.767347
# NumberFloorsofBuilding       6.952397
# dtype: float64

# %%
df.var()
# Out:
# C:\Users\RUTUJA\AppData\Local\Temp\ipykernel_18724\1568254755.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.var()
# Unnamed: 0                5.273326e+07
# NumberFloorsofBuilding    4.833582e+01
# dtype: float64

# %%
categorical_summary = df.describe(include='object')
categorical_summary
# Out:
#        district      price                                            address  \
# count     25155      25155                                              25155
# unique       39       2825                                               1638
# top     sariyer  1,350,000  ['Anasayfa', 'Satılık Residence', 'İstanbul Sa...
# freq       1449        371                                                452
#
#         AdUpdateDate Category GrossSquareMeters BuildingAge UsingStatus  \
# count          25155    25155             25155       25155       25155
# unique           186        1               584          10           3
# top     04 Mart 2022  Satılık            100 m2    0 (Yeni)         Boş
# freq            1605    25155              1478        7333       11139
#
#        EligibilityForInvestment BuildStatus  ...  PriceStatus RentalIncome  \
# count                     21506       11231  ...        25155         5815
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0  NumberFloorsofBuilding
# count  25155.000000            25155.000000
# mean   12577.000000                7.757782
# std     7261.767347                6.952397
# min        0.000000                1.000000
# 25%     6288.500000                4.000000
# 50%    12577.000000                5.000000
# 75%    18865.500000                8.000000
# max    25154.000000               71.000000

# %%
# Assuming df is your DataFrame
df['BuildingAge'] = pd.to_numeric(df['BuildingAge'], errors='coerce')

# Drop rows where the conversion failed (NaN values after coercing to numeric)
df.dropna(subset=['BuildingAge'], inplace=True)
df
# Out:
#        Unnamed: 0     district       price  \
# 26             26   arnavutkoy     515,000
# 34             34   arnavutkoy     480,000
# 35             35   arnavutkoy     715,000
# 51             51   arnavutkoy   1,000,000
# 56             56   arnavutkoy     675,000
# ...           ...          ...         ...
# 25131       25131  zeytinburnu  14,000,000
# 25137       25137  zeytinburnu   2,650,000
# 25146       25146  zeytinburnu   5,150,000
# 25148       25148  zeytinburnu  22,000,000
# 25151       25151  zeytinburnu   1,100,000
#
#                                                  address    AdUpdateDate  \
# 26     ['Anasayfa', 'Satılık Daire', 'İstanbul Satılı...    02 Mart 2022
# 34     ['Anasayfa', 'Satılık Daire', 'İstanbul Satılı...    01 Mart 2022
# 35     ['Anasayfa', 'Satılık Daire', 'İstanbul Satılı...    01 Mart 2022
# 51     ['Anasayfa', 'Satılık Daire', 'İstanbul Satılı...   26 Şubat 2022
# 56     ['Anasayfa', 'Satılık Daire', 'İstanbul Satılı...    02 Mart 2022
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                   int64
# district                    object
# price                       object
# address                     object
# AdUpdateDate                object
# Category                    object
# GrossSquareMeters           object
# BuildingAge                 object
# NumberFloorsofBuilding       int64
# UsingStatus                 object
# EligibilityForInvestment    object
# BuildStatus                 object
# TitleStatus                 object
# ItemStatus                  object
# NumberOfBathrooms           object
# NumberOfWCs                 object
# AdCreationDate              object
# Type                        object
# NetSquareMeters             object
# NumberOfRooms               object
# FloorLocation               object
# HeatingType                 object
# CreditEligibility           object
# InsideTheSite               object
# StructureType               object
# MortgageStatus              object
# Swap                        object
# ...

# %%
df.groupby('BuildingAge')['price'].describe()
# Out:
#             count unique        top freq
# BuildingAge
# 1.0           798    374    850,000   16
# 2.0           963    426  1,100,000   21
# 3.0          1202    482  1,350,000   22
# 4.0          2199    711  1,350,000   35
