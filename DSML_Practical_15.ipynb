# %% [markdown]
# 15. Use the dataset 'titanic'. The dataset contains 891 rows and contains
# information about the passengers who boarded the unfortunate Titanic
# ship. Use the Seaborn library to see if we can find any patterns in the data.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset from Seaborn
titanic_data = sns.load_dataset('titanic')

# %%
titanic_data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic_data.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
datatype=titanic_data.convert_dtypes()
datatype.dtypes
# Out:
# survived          Int64
# pclass            Int64
# sex              string
# age             Float64
# sibsp             Int64
# parch             Int64
# fare            Float64
# embarked         string
# class          category
# who              string
# adult_male      boolean
# deck           category
# embark_town      string
# alive            string
# alone           boolean
# dtype: object

# %%
# Set the style of seaborn
sns.set(style="whitegrid")

# Visualize patterns using different plots
# Examples:
# 1. Countplot for survival
plt.figure(figsize=(8, 5))
sns.countplot(x='survived', data=titanic_data, palette='Set1')
plt.title('Survival Count')
plt.show()

# 2. Countplot for survival based on passenger class
plt.figure(figsize=(10, 6))
sns.countplot(x='survived', hue='pclass', data=titanic_data, palette='viridis')
plt.title('Survival Count based on Passenger Class')
plt.show()

# 3. Distribution of age
plt.figure(figsize=(10, 6))
sns.histplot(titanic_data['age'].dropna(), kde=True, color='purple', bins=30)
plt.title('Distribution of Age')
plt.show()

# 4. Scatter plot for fare and age
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='fare', hue='survived', data=titanic_data, palette='coolwarm')
plt.title('Scatter plot of Fare vs. Age with Survival')
plt.show()

# 5. Heatmap for correlation between variables
plt.figure(figsize=(10, 8))
correlation_matrix = titanic_data.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
sns.countplot(x='survived', data=titanic_data)
plt.title('Survival Count')
plt.show()

# %%
sns.countplot(x='sex',hue='survived',data=titanic_data)
plt.show()

# %%
sns.countplot(x='survived',hue='pclass',data=titanic_data)
plt.title("Survival based on Pclass")
plt.show()

# %%
#kde=kernal density estimation 
sns.histplot(titanic_data['age'].dropna(), kde=True, color='purple', bins=30)
plt.title('Distribution of Age')
plt.show()

# %%
correlation_matrix = titanic_data.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
sns.boxplot(x='age',y='sex',data=titanic_data)
# Out:
# <AxesSubplot:xlabel='age', ylabel='sex'>

# %%
# 4. Scatter plot for fare and age
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='fare', hue='survived', data=titanic_data, palette='coolwarm')
plt.title('Scatter plot of Fare vs. Age with Survival')
plt.show()

# %%
sns.scatterplot(x='pclass',y='fare',hue='sex',data=titanic_data)
plt.show()

# %%
sns.pairplot(titanic_data[['age','survived','pclass']])

# %%
sns.countplot(x='alone',hue='sex',data=titanic_data)
plt.show()

# %%
sns.histplot(x='fare',data=titanic_data,color='green',kde='true',bins=30)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Count'>

# %%
data = [titanic_data[titanic_data['age'] <= 19].count()[0],titanic_data[(20 <= titanic_data['age']) & (titanic_data['age'] <= 50)].count()[0],titanic_data[titanic_data['age'] > 50].count()[0]]

labels = ["The Childrens","The Young","The Old"]

sns.barplot(y=labels,x=data)

plt.show()
