# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# Out:
# C:\Users\RUTUJA\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df=pd.read_csv("D:\Datasets\Datasets\IRIS.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.size
# Out:
# 750

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
datatype=df.convert_dtypes()
datatype.dtypes
# Out:
# sepal_length    Float64
# sepal_width     Float64
# petal_length    Float64
# petal_width     Float64
# species          string
# dtype: object

# %%
df.std()
# Out:
# C:\Users\RUTUJA\AppData\Local\Temp\ipykernel_16792\1413159688.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# sepal_length    0.828066
# sepal_width     0.433594
# petal_length    1.764420
# petal_width     0.763161
# dtype: float64

# %%
#For single column
df['sepal_length'].std()
# Out:
# 0.8280661279778629

# %%
df.mean()
# Out:
# C:\Users\RUTUJA\AppData\Local\Temp\ipykernel_16792\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# sepal_length    5.843333
# sepal_width     3.054000
# petal_length    3.758667
# petal_width     1.198667
# dtype: float64

# %%
df.median()
# Out:
# C:\Users\RUTUJA\AppData\Local\Temp\ipykernel_16792\530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal_width     1.30
# dtype: float64

# %%
df.mode()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width          species
# 0           5.0          3.0           1.5          0.2      Iris-setosa
# 1           NaN          NaN           NaN          NaN  Iris-versicolor
# 2           NaN          NaN           NaN          NaN   Iris-virginica

# %%
sns.boxplot(x=df['sepal_length'])
plt.title('Boxplot of sepal_length')
plt.show()

# %%
sns.boxplot(x=df['sepal_width'])
plt.title('Boxplot of sepal_width')
plt.show()

# %%
sns.boxplot(x=df['petal_length'])
plt.title('Boxplot of petal_length')
plt.show()

# %%
sns.boxplot(x=df['petal_width'])
plt.title('Boxplot of petal_width')
plt.show()

# %%
# Function to identify and plot outliers
def plot_outliers(column_data, column_name):
    plt.figure(figsize=(8, 6))
    
    # Calculate IQR
    Q1 = np.percentile(column_data, 25)
    Q3 = np.percentile(column_data, 75)
    IQR = Q3 - Q1
    
    # Define the lower and upper bounds for outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Identify outliers
    outliers = column_data[(column_data < lower_bound) | (column_data > upper_bound)]
    
    # Plot the boxplot
    plt.boxplot(column_data, vert=False)
    
    # Highlight the outliers
    plt.scatter(outliers, [1] * len(outliers), color='red', label='Outliers')
    
    plt.title(f'Outliers in {column_name}')
    plt.xlabel(column_name)
    plt.yticks([])
    plt.legend()
    plt.show()

# %%
plot_outliers(df['sepal_length'], 'sepal_length')

# %%
plot_outliers(df['sepal_width'], 'sepal_width')

# %%
plot_outliers(df['petal_length'], 'petal_length')

# %%
plot_outliers(df['petal_width'], 'petal_width')

# %%
df['sepal_length'].hist(bins=30)
plt.title('Histogram of sepal_length')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %%
df['sepal_width'].hist(bins=30)
plt.title('Histogram of sepal_width')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %%
df['petal_length'].hist(bins=30)
plt.title('Histogram of petal_length')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %%
df['petal_width'].hist(bins=30)
plt.title('Histogram of petal_width')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %%
import sklearn.metrics
print(sorted(dir(sklearn)))
# Out:
# ['__SKLEARN_SETUP__', '__all__', '__builtins__', '__cached__', '__check_build', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_config', '_distributor_init', '_loss', 'base', 'clone', 'config_context', 'exceptions', 'externals', 'get_config', 'logger', 'logging', 'metrics', 'os', 'preprocessing', 'random', 'set_config', 'setup_module', 'show_versions', 'sys', 'utils']

# %%
#count the occurance of each value
value_counts = df['column_name'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'column_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
plt.hist2d(df['sepal_length'], df['sepal_width'], bins=(5, 5), cmap='Blues')
# Out:
# (array([[ 4.,  2., 22.,  4.,  0.],
#         [ 3., 13.,  9., 13.,  3.],
#         [ 4., 23., 14.,  0.,  1.],
#         [ 0.,  4., 20.,  0.,  0.],
#         [ 0.,  4.,  4.,  3.,  0.]]),
#  array([4.3 , 5.02, 5.74, 6.46, 7.18, 7.9 ]),
#  array([2.  , 2.48, 2.96, 3.44, 3.92, 4.4 ]),
#  <matplotlib.collections.QuadMesh at 0x2f0c06f2730>)

# %%
# Plotting a boxplot with Seaborn
ax = sns.boxplot(x=df['sepal_width'])
plt.title('Boxplot of sepal_width')

# Identifying outliers using IQR method
Q1 = df['sepal_width'].quantile(0.25)
Q3 = df['sepal_width'].quantile(0.75)
IQR = Q3 - Q1

outliers = df[(df['sepal_width'] < Q1 - 1.5 * IQR) | (df['sepal_width'] > Q3 + 1.5 * IQR)]

plt.show()

# Printing the identified outliers
print("Outliers:")
print(outliers)
# Out:
# Outliers:
#     sepal_length  sepal_width  petal_length  petal_width          species
# 15           5.7          4.4           1.5          0.4      Iris-setosa
# 32           5.2          4.1           1.5          0.1      Iris-setosa
# 33           5.5          4.2           1.4          0.2      Iris-setosa
# 60           5.0          2.0           3.5          1.0  Iris-versicolor

# %%
sns.boxplot(x=df[df['species']=='Iris-setosa']['sepal_width'])
# Out:
# <AxesSubplot:xlabel='sepal_width'>

# %%
sns.boxplot(x=df['sepal_width'])
Q1=df['sepal_width'].quantile(0.25)
Q3=df['sepal_width'].quantile(0.75)
IQR=Q3-Q1
# outliers = df[(df['sepal_width'] < Q1 - 1.5 * IQR) | (df['sepal_width'] > Q3 + 1.5 * IQR)]
outliers=df[(df['sepal_width']<Q1-1.5*IQR)|(df['sepal_width']>Q3+1.5*IQR)]
print(outliers)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width          species
# 15           5.7          4.4           1.5          0.4      Iris-setosa
# 32           5.2          4.1           1.5          0.1      Iris-setosa
# 33           5.5          4.2           1.4          0.2      Iris-setosa
# 60           5.0          2.0           3.5          1.0  Iris-versicolor
